# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dict = {
    "header":16,
    "encoding":"utf-8",
    "on_bad_lines":"warn",
    "skip_blank_lines":True,
    "infer_datetime_format":True,
    # "dtype":"float64"
}

# %%
result = pd.read_csv(r".\xrd-utf8.csv",**dict)
# Out:
# b'Skipping line 530: expected 10 fields, saw 712\nSkipping line 531: expected 10 fields, saw 712\nSkipping line 532: expected 10 fields, saw 712\nSkipping line 533: expected 10 fields, saw 712\nSkipping line 534: expected 10 fields, saw 712\nSkipping line 535: expected 10 fields, saw 712\nSkipping line 536: expected 10 fields, saw 712\nSkipping line 537: expected 10 fields, saw 712\nSkipping line 538: expected 10 fields, saw 712\nSkipping line 539: expected 10 fields, saw 712\nSkipping line 540: expected 10 fields, saw 712\nSkipping line 541: expected 10 fields, saw 712\nSkipping line 542: expected 10 fields, saw 712\nSkipping line 543: expected 10 fields, saw 712\nSkipping line 544: expected 10 fields, saw 712\nSkipping line 545: expected 10 fields, saw 712\nSkipping line 546: expected 10 fields, saw 712\nSkipping line 547: expected 10 fields, saw 712\nSkipping line 548: expected 10 fields, saw 712\nSkipping line 549: expected 10 fields, saw 712\nSkipping line 550: expected 10 field
# ...

# %%
result
# Out:
#      Unnamed: 0       α   γRi  γR （ピーク強度）    積分強度 α   積分強度 γ   ピーク強度 α  \
# 0           NaN    0.00  24.6        35.7  194014.0  53348.9  141615.2
# 1           NaN    0.72  24.4        35.6  193692.4  52790.5  141461.4
# 2           NaN    1.44  24.3        35.5  193621.3  52417.8  141451.6
# 3           NaN    2.16  24.2        35.4  193651.3  52054.9  141514.9
# 4           NaN    2.88  24.1        35.4  193865.8  51720.6  141686.2
# ..          ...     ...   ...         ...       ...      ...       ...
# 496         NaN  357.12  24.8        35.9  193250.5  53885.5  141472.9
# 497         NaN  357.84  24.8        35.9  193344.2  53861.8  141424.0
# 498         NaN  358.56  24.8        35.8  193425.2  53705.5  141390.8
# 499         NaN  359.28  24.6        35.7  193220.4  53250.1  141241.4
# 500         NaN  プロファイル   NaN         NaN       NaN      NaN       NaN
#
#      ピーク強度 γ  半価幅 α  半価幅 γ
# 0    62149.8   6.70   2.03
# 1    61757.8   6.69   2.02
# 2    61549.1   6.69   2.01
# ...
